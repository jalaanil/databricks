-- %%
%sql
CREATE CATALOG IF NOT EXISTS sales;

-- %%
%sql
USE CATALOG sales

-- %%
%sql
CREATE SCHEMA IF NOT EXISTS sales;

-- %%
%sql
USE SCHEMA sales;
DROP TABLE PRODUCT;
CREATE TABLE PRODUCT( product_id INTEGER , name STRING , price INTEGER)

-- %%
%sql
DESCRIBE DETAIL sales.sales.product;

-- %%
%sql

drop table CUSTOMER;
CREATE TABLE CUSTOMER( Customer_Id INTEGER , name STRING , Location STRING)

-- %%
%sql
SHOW CATALOGS

-- %%
%sql
CREATE TABLE ORDER( ORDER_ID INTEGER , ORDER_DATE DATE , Customer_Id INTEGER )

-- %%
%sql
show tables

-- %%
%sql
CREATE VOLUME sales.sales.incoming;

-- %%
%sql
describe TABLE product

-- %%
%sql
drop table sales.sales.order

-- %%
%sql
CREATE TABLE order (
  order_id STRING,
  customer_id STRING,
  order_date DATE
);

-- %%
%sql
CREATE TABLE order_detail (
  order_id STRING,
  product_id STRING,
  qty INT,
  price DECIMAL(10,2)
);

-- %%
select * from sales.sales.order_detail
